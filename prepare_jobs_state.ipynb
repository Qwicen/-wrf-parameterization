# %%
import json
import os

# %%
import logging
import time

current_ts = int(time.time())

logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.DEBUG,
    datefmt='%Y-%m-%d %H:%M:%S',
    filename=f'script_prepare_jobs_state_{current_ts}.log',
    encoding='utf-8',
)

# %%
with open(os.path.join("/home/jovyan/work/ship/calculate_points", "jobs_state_new.json")) as f:
    state = json.load(f)
    completed_jobs = state["completed_jobs"]

# %%
class JobSchedulerContext:
    def __init__(self):
        pass

    @classmethod
    def make_job_context(cls, job_id, wrf_params, local_work_dir, job_work_dir, only_geo_params=False):

        kuber_job_prefix = 'calculate-geo-middle' if only_geo_params else 'calculate-points'
        results_dir_name = 'geo_results_middle' if only_geo_params else 'results'

        return {
            "id": job_id,
            "kuber_job_id": f"{kuber_job_prefix}-{job_id}",
            "wrf_params": wrf_params,
            "local_dir_with_results": os.path.join(local_work_dir, results_dir_name, job_id),
            "job_dir_with_results": os.path.join(job_work_dir, results_dir_name, job_id),
            "score": None,
            "error_msg": None
        }

    @classmethod
    def get_scheduler_job_id(cls, job_context):
        return job_context["id"]

    @classmethod
    def get_kuber_job_id(cls, job_context):
        return job_context["kuber_job_id"]

    @classmethod
    def get_wrf_params(cls, job_context):
        return job_context["wrf_params"]

    @classmethod
    def get_local_dir_with_results(cls, job_context):
        return job_context["local_dir_with_results"]

    @classmethod
    def get_job_dir_with_results(cls, job_context):
        return job_context["job_dir_with_results"]

    @classmethod
    def get_score(cls, job_context):
        return job_context["score"]

    @classmethod
    def set_score_result(cls, job_context, score_result):
        job_context["score_result"] = score_result

    @classmethod
    def set_error_msg(cls, job_context, error_msg):
        job_context["error_msg"] = error_msg

    @classmethod
    def calculate_expected_count_of_results_files(cls, job_context):
        wrf_params = JobSchedulerContext.get_wrf_params(job_context)
        start_date = datetime.strptime(wrf_params["START_DATE"], '%Y-%m-%d_%H:%M:%S')
        end_date = datetime.strptime(wrf_params["END_DATE"], '%Y-%m-%d_%H:%M:%S')
        interval_in_seconds = 3600
        delta_in_seconds = (end_date - start_date).total_seconds()
        return delta_in_seconds // interval_in_seconds + 1

# %%
import xarray as xr
import pandas
from sklearn.metrics import mean_squared_error
from scipy.interpolate import LinearNDInterpolator
import numpy as np

class JobScoreCalculator:
    def __init__(self, real_temperature_filename):
        self._temp_df = pandas.read_csv(real_temperature_filename)
        self._temp_df["time"] = pandas.to_datetime(self._temp_df["time"], format='%Y-%m-%d %H:%M:%S', errors='ignore')

    @staticmethod
    def _get_data_from_result_file(path):
        logging.debug(f"_get_data_from_result_file({path})")
        data = xr.open_dataset(path)
        return data

    def _get_meteostations_data_in_grid_area(self, wrf_data, timestamp):
        logging.debug(f"_get_meteostations_data_in_grid_area")
        min_long = wrf_data.XLONG.data.min()
        max_long = wrf_data.XLONG.data.max()

        min_lat = wrf_data.XLAT.data.min()
        max_lat = wrf_data.XLAT.data.max()

        logging.debug(f"min_long={min_long}, max_long={max_long}, min_lat={min_lat}, max_lat={max_lat}, timestamp={timestamp}")

        df = self._temp_df[
            (self._temp_df["longitude"] > min_long) & (self._temp_df["longitude"] < max_long) &
            (self._temp_df["latitude"] > min_lat) & (self._temp_df["latitude"] < max_lat) &
            (self._temp_df["time"] == timestamp)
        ]

        return df.reset_index()

    @staticmethod
    def _calculate_interpolated_wrf_temps(wrf_data, meteostations_coords):
        logging.debug(f"_calculate_interpolated_wrf_temps")
        flat_grid_lon = wrf_data.XLONG.data.reshape(-1)
        flat_grid_lat = wrf_data.XLAT.data.reshape(-1)
        temp = wrf_data["T2"].data.reshape(-1)
        logging.debug(f"flat_grid_lon {flat_grid_lon}")
        logging.debug(f"flat_grid_lat {flat_grid_lat}")
        temp = temp - 273.15
        logging.debug(f"temp_ {temp}")
        temp_interp = LinearNDInterpolator(list(zip(flat_grid_lon, flat_grid_lat)), temp)
        return temp_interp([coord[0] for coord in meteostations_coords], [coord[1] for coord in meteostations_coords])

    def calculate_job_score(self, timestamped_paths, return_raw=False):
        logging.debug("job score calc started")
        real_temperatures = np.array([])
        wrf_calculated_temperatures = np.array([])

        dropped_points_cnt_by_path = []
        points_cnt_by_path = []
        used_meteostations = set()

        for path in timestamped_paths:
            filename = os.path.basename(path)
            timestamp_str = filename[-19:]
            timestamp = pandas.to_datetime(timestamp_str, format='%Y-%m-%d_%H:%M:%S', errors='ignore')
            wrf_data = self._get_data_from_result_file(path)

            meteostations_data = self._get_meteostations_data_in_grid_area(wrf_data, timestamp)

            if meteostations_data.empty:
                logging.info(f"No meteo data found for {timestamp}")
                points_cnt_by_path.append(0)
                dropped_points_cnt_by_path.append(0)
                continue

            meteostations_temperatures = []
            meteostations_coordinates = []

            for _, row in meteostations_data.iterrows():
                meteostations_temperatures.append(row["temperature"])
                meteostations_coordinates.append((row["longitude"], row["latitude"]))

            meteostations_temperatures = np.array(meteostations_temperatures)
            meteostations_coordinates = np.array(meteostations_coordinates)

            wrf_interpolated_temps = self._calculate_interpolated_wrf_temps(wrf_data, meteostations_coordinates)

            bool_nan_indexes = np.isnan(wrf_interpolated_temps)
            logging.debug(f"will drop {bool_nan_indexes.sum()} points")
            bool_not_nan_indexes = ~bool_nan_indexes
            wrf_interpolated_temps = wrf_interpolated_temps[bool_not_nan_indexes]
            meteostations_temperatures = meteostations_temperatures[bool_not_nan_indexes]
            meteostations_coordinates = meteostations_coordinates[bool_not_nan_indexes]

            for coords in meteostations_coordinates:
                used_meteostations.add((coords[0], coords[1]))
            points_cnt_by_path.append(len(real_temperatures))
            dropped_points_cnt_by_path.append(int(bool_nan_indexes.sum()))

            real_temperatures = np.concatenate((real_temperatures, meteostations_temperatures))
            wrf_calculated_temperatures = np.concatenate((wrf_calculated_temperatures, wrf_interpolated_temps))

        logging.debug(f"real_temperatures {real_temperatures}")
        logging.debug(f"wrf_calculated_temperatures {wrf_calculated_temperatures}")
        assert len(wrf_calculated_temperatures) == len(real_temperatures)
        assert wrf_calculated_temperatures.size
        score = {}
        if return_raw:
            return real_temperatures, wrf_calculated_temperatures
        value = mean_squared_error(real_temperatures, wrf_calculated_temperatures, squared=False)
        score["value"] = value
        logging.debug(f"score {value}")
        score["points_count_by_path"] = points_cnt_by_path
        score["dropped_points_count_by_path"] = dropped_points_cnt_by_path
        score["total_used_meteostations"] = [station for station in used_meteostations]
        return score

# %%
calculator = JobScoreCalculator(real_temperature_filename="/home/jovyan/work/ship/calculate_points/last_prepared_noaa_data_morozyto.csv")

# %%
import glob

def get_paths(pattern): # f"{JobSchedulerContext.get_local_dir_with_results(job_context)}/auxhist7_d01_2020-07-{day}_*"
    paths = glob.glob(pattern)
    paths.sort()
    return paths

# %%
def process_job(job):
    if "score_result" in job:
        del job["score_result"]

    three_hours_paths = f"{JobSchedulerContext.get_local_dir_with_results(job)}/auxhist7_d01_2020-07-15_0[123]:00:00"
    job["score_result_3h"] = calculator.calculate_job_score(timestamped_paths=get_paths(three_hours_paths))

    one_day_paths = f"{JobSchedulerContext.get_local_dir_with_results(job)}/auxhist7_d01_2020-07-15_2[123]:00:00"
    job["score_result_1d"] = calculator.calculate_job_score(timestamped_paths=get_paths(one_day_paths))

    three_days_paths = f"{JobSchedulerContext.get_local_dir_with_results(job)}/auxhist7_d01_2020-07-17_2[123]:00:00"
    job["score_result_3d"] = calculator.calculate_job_score(timestamped_paths=get_paths(three_days_paths))

    seven_days_paths = f"{JobSchedulerContext.get_local_dir_with_results(job)}/auxhist7_d01_2020-07-21_2[123]:00:00"
    job["score_result_7d"] = calculator.calculate_job_score(timestamped_paths=get_paths(seven_days_paths))

    return job

# %%
new_state = {}
new_state["completed_jobs"] = []
new_state["failed_jobs"] = []
new_state["running_jobs"] = []

for job in completed_jobs:
    new_state["completed_jobs"].append(process_job(job))

# %%
tmp_path = "/home/jovyan/work/ship/calculate_points/jobs_state_new.json"
with open(tmp_path, 'w') as f:
    json.dump(new_state, f)

# %%
new_state["completed_jobs"]
# Out:
# [{'id': '0',
#   'kuber_job_id': 'calculate-points-0',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '66.00',
#    'LON': '59.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/0',
#   'job_dir_with_results': '/share/calculate_points/results/0',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.6515771790171356,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 2],
#    'total_used_meteostations': [(60.883333, 64.283333),
#     (52.5625, 66.258333),
#     (57.135, 65.126111),
#     (65.05, 63.933333),
#     (56.905833, 65.984167),
#     (53.805833, 63.575278),
#     (64.716667, 65.483333),
#     (57.616667, 64.266667),
#     (62.1, 63.65),
#     (53.966667, 65.033333),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (63.971667, 67.491667),
#     (64.06, 67.05),
#     (55.496667, 68.540556)]},
#   'score_result_1d': {'value': 2.3710645734506164,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(60.883333, 64.283333),
#     (65.05, 63.933333),
#     (57.135, 65.126111),
#     (56.905833, 65.984167),
#     (53.805833, 63.575278),
#     (64.716667, 65.483333),
#     (62.1, 63.65),
#     (53.966667, 65.033333),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (63.971667, 67.491667),
#     (64.06, 67.05),
#     (55.496667, 68.540556)]},
#   'score_result_3d': {'value': 1.6563396052289114,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(60.883333, 64.283333),
#     (65.05, 63.933333),
#     (57.135, 65.126111),
#     (56.905833, 65.984167),
#     (53.805833, 63.575278),
#     (64.716667, 65.483333),
#     (62.1, 63.65),
#     (53.966667, 65.033333),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (63.971667, 67.491667),
#     (64.06, 67.05),
#     (55.496667, 68.540556)]},
#   'score_result_7d': {'value': 3.1824517560229744,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(60.883333, 64.283333),
#     (65.05, 63.933333),
#     (57.135, 65.126111),
#     (56.905833, 65.984167),
#     (53.805833, 63.575278),
#     (64.716667, 65.483333),
#     (62.1, 63.65),
#     (53.966667, 65.033333),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (63.971667, 67.491667),
#     (64.06, 67.05),
#     (55.496667, 68.540556)]}},
#  {'id': '1',
#   'kuber_job_id': 'calculate-points-1',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 5,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '84.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/1',
#   'job_dir_with_results': '/share/calculate_points/results/1',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.5787546304485265,
#    'points_count_by_path': [0, 4, 8],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_1d': {'value': 3.3505298417081284,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_3d': {'value': 2.645911571645142,
#    'points_count_by_path': [0, 25, 29],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_7d': {'value': 4.459720044582052,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]}},
#  {'id': '2',
#   'kuber_job_id': 'calculate-points-2',
#   'wrf_params': {'MP_PHYSICS': 8,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 7,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '112.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/2',
#   'job_dir_with_results': '/share/calculate_points/results/2',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.1626341571974343,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [1, 1, 3],
#    'total_used_meteostations': [(113.306, 52.026299),
#     (110.466667, 51.366667),
#     (109.633333, 53.616667),
#     (113.483333, 52.083333),
#     (113.619444, 55.486111),
#     (112.783333, 53.2),
#     (115.166667, 52.65),
#     (111.557778, 52.538333),
#     (112.466667, 51.35),
#     (115.616667, 53.533333),
#     (109.966667, 52.766667),
#     (114.516667, 51.1),
#     (108.291111, 52.986111),
#     (116.033333, 51.866667),
#     (109.016667, 53.416667),
#     (113.580556, 54.441667),
#     (108.75, 50.366667),
#     (108.866667, 51.316667)]},
#   'score_result_1d': {'value': 2.1279126201997536,
#    'points_count_by_path': [0, 18, 19],
#    'dropped_points_count_by_path': [3, 1, 1],
#    'total_used_meteostations': [(113.306, 52.026299),
#     (110.466667, 51.366667),
#     (109.633333, 53.616667),
#     (113.483333, 52.083333),
#     (113.619444, 55.486111),
#     (112.783333, 53.2),
#     (115.166667, 52.65),
#     (111.557778, 52.538333),
#     (112.466667, 51.35),
#     (115.616667, 53.533333),
#     (109.966667, 52.766667),
#     (114.516667, 51.1),
#     (108.291111, 52.986111),
#     (116.033333, 51.866667),
#     (109.016667, 53.416667),
#     (113.580556, 54.441667),
#     (108.75, 50.366667),
#     (108.866667, 51.316667)]},
#   'score_result_3d': {'value': 3.4650766199916383,
#    'points_count_by_path': [0, 18, 19],
#    'dropped_points_count_by_path': [3, 1, 1],
#    'total_used_meteostations': [(113.306, 52.026299),
#     (110.466667, 51.366667),
#     (109.633333, 53.616667),
#     (113.483333, 52.083333),
#     (113.619444, 55.486111),
#     (112.783333, 53.2),
#     (115.166667, 52.65),
#     (111.557778, 52.538333),
#     (112.466667, 51.35),
#     (115.616667, 53.533333),
#     (109.966667, 52.766667),
#     (114.516667, 51.1),
#     (108.291111, 52.986111),
#     (116.033333, 51.866667),
#     (109.016667, 53.416667),
#     (113.580556, 54.441667),
#     (108.75, 50.366667),
#     (108.866667, 51.316667)]},
#   'score_result_7d': {'value': 6.218124201125981,
#    'points_count_by_path': [0, 18, 19],
#    'dropped_points_count_by_path': [3, 1, 1],
#    'total_used_meteostations': [(113.306, 52.026299),
#     (110.466667, 51.366667),
#     (109.633333, 53.616667),
#     (113.483333, 52.083333),
#     (113.619444, 55.486111),
#     (112.783333, 53.2),
#     (115.166667, 52.65),
#     (111.557778, 52.538333),
#     (112.466667, 51.35),
#     (115.616667, 53.533333),
#     (109.966667, 52.766667),
#     (114.516667, 51.1),
#     (108.291111, 52.986111),
#     (116.033333, 51.866667),
#     (109.016667, 53.416667),
#     (113.580556, 54.441667),
#     (108.75, 50.366667),
#     (108.866667, 51.316667)]}},
#  {'id': '3',
#   'kuber_job_id': 'calculate-points-3',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '55.00',
#    'LON': '28.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/3',
#   'job_dir_with_results': '/share/calculate_points/results/3',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.2940003676966259,
#    'points_count_by_path': [0, 2, 4],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(30.963056, 52.401944),
#     (29.126944, 53.208611),
#     (28.9, 57.016667),
#     (32.433333, 54.416667),
#     (32.066667, 54.75),
#     (31.633333, 56.483333),
#     (28.030701, 53.8825),
#     (28.141111, 53.491667),
#     (31.003611, 53.451111),
#     (28.497778, 54.265556),
#     (31.016701, 52.527),
#     (30.943889, 54.303889),
#     (27.94, 55.820833),
#     (30.249167, 55.252778),
#     (30.443889, 54.502778),
#     (28.716667, 56.716667),
#     (30.616667, 56.35),
#     (31.183333, 57.15),
#     (32.071111, 53.358611),
#     (29.311944, 53.494444),
#     (28.751667, 55.474722),
#     (31.183333, 55.616667),
#     (28.997778, 53.828333),
#     (31.6, 53.016667),
#     (30.043611, 52.894167)]},
#   'score_result_1d': {'value': 2.2230400991481076,
#    'points_count_by_path': [0, 17, 19],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(30.616667, 56.35),
#     (31.183333, 57.15),
#     (30.963056, 52.401944),
#     (29.126944, 53.208611),
#     (32.071111, 53.358611),
#     (31.6, 53.016667),
#     (28.9, 57.016667),
#     (31.016701, 52.527),
#     (27.94, 55.820833),
#     (30.443889, 54.502778),
#     (30.249167, 55.252778),
#     (28.716667, 56.716667),
#     (28.030701, 53.8825),
#     (31.633333, 56.483333),
#     (31.183333, 55.616667),
#     (32.433333, 54.416667),
#     (32.066667, 54.75)]},
#   'score_result_3d': {'value': 1.8832490580158017,
#    'points_count_by_path': [0, 17, 19],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(30.616667, 56.35),
#     (31.183333, 57.15),
#     (30.963056, 52.401944),
#     (29.126944, 53.208611),
#     (32.071111, 53.358611),
#     (31.6, 53.016667),
#     (28.9, 57.016667),
#     (31.016701, 52.527),
#     (27.94, 55.820833),
#     (30.443889, 54.502778),
#     (30.249167, 55.252778),
#     (28.716667, 56.716667),
#     (28.030701, 53.8825),
#     (31.633333, 56.483333),
#     (31.183333, 55.616667),
#     (32.433333, 54.416667),
#     (32.066667, 54.75)]},
#   'score_result_7d': {'value': 1.6846073561706727,
#    'points_count_by_path': [0, 17, 19],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(30.616667, 56.35),
#     (31.183333, 57.15),
#     (30.963056, 52.401944),
#     (29.126944, 53.208611),
#     (32.071111, 53.358611),
#     (31.6, 53.016667),
#     (28.9, 57.016667),
#     (31.016701, 52.527),
#     (27.94, 55.820833),
#     (30.443889, 54.502778),
#     (30.249167, 55.252778),
#     (28.716667, 56.716667),
#     (28.030701, 53.8825),
#     (31.633333, 56.483333),
#     (31.183333, 55.616667),
#     (32.433333, 54.416667),
#     (32.066667, 54.75)]}},
#  {'id': '4',
#   'kuber_job_id': 'calculate-points-4',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 5,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 1,
#    'KM_OPT': 4,
#    'LAT': '54.00',
#    'LON': '58.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/4',
#   'job_dir_with_results': '/share/calculate_points/results/4',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 3.481697596112601,
#    'points_count_by_path': [0, 4, 8],
#    'dropped_points_count_by_path': [0, 0, 2],
#    'total_used_meteostations': [(55.874401, 54.557499),
#     (57.452222, 52.238611),
#     (62.1, 53.78),
#     (58.223056, 51.873056),
#     (55.933611, 53.603333),
#     (61.21, 52.18),
#     (61.3, 55.15),
#     (55.553889, 55.404444),
#     (54.147222, 54.024722),
#     (56.573611, 56.110278),
#     (60.3, 56.083333),
#     (55.815, 54.710556),
#     (61.5033, 55.305801),
#     (61.2, 52.71),
#     (61.616667, 54.083333),
#     (59.083333, 53.35),
#     (54.75, 52.933333),
#     (58.755699, 53.393101),
#     (53.733333, 56.466667),
#     (55.078333, 51.6925),
#     (55.456699, 51.795799)]},
#   'score_result_1d': {'value': 3.188146927076659,
#    'points_count_by_path': [0, 21, 25],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(55.874401, 54.557499),
#     (57.452222, 52.238611),
#     (62.1, 53.78),
#     (58.223056, 51.873056),
#     (55.933611, 53.603333),
#     (61.21, 52.18),
#     (61.3, 55.15),
#     (55.553889, 55.404444),
#     (54.147222, 54.024722),
#     (56.573611, 56.110278),
#     (60.3, 56.083333),
#     (55.815, 54.710556),
#     (61.5033, 55.305801),
#     (61.2, 52.71),
#     (61.616667, 54.083333),
#     (59.083333, 53.35),
#     (54.75, 52.933333),
#     (58.755699, 53.393101),
#     (53.733333, 56.466667),
#     (55.078333, 51.6925),
#     (55.456699, 51.795799)]},
#   'score_result_3d': {'value': 2.7148589462294583,
#    'points_count_by_path': [0, 21, 25],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(55.874401, 54.557499),
#     (57.452222, 52.238611),
#     (62.1, 53.78),
#     (58.223056, 51.873056),
#     (55.933611, 53.603333),
#     (61.21, 52.18),
#     (61.3, 55.15),
#     (55.553889, 55.404444),
#     (54.147222, 54.024722),
#     (56.573611, 56.110278),
#     (60.3, 56.083333),
#     (55.815, 54.710556),
#     (61.5033, 55.305801),
#     (61.2, 52.71),
#     (61.616667, 54.083333),
#     (59.083333, 53.35),
#     (54.75, 52.933333),
#     (58.755699, 53.393101),
#     (53.733333, 56.466667),
#     (55.078333, 51.6925),
#     (55.456699, 51.795799)]},
#   'score_result_7d': {'value': 1.5297078948412293,
#    'points_count_by_path': [0, 21, 25],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(55.874401, 54.557499),
#     (57.452222, 52.238611),
#     (62.1, 53.78),
#     (58.223056, 51.873056),
#     (55.933611, 53.603333),
#     (61.21, 52.18),
#     (61.3, 55.15),
#     (55.553889, 55.404444),
#     (54.147222, 54.024722),
#     (56.573611, 56.110278),
#     (60.3, 56.083333),
#     (55.815, 54.710556),
#     (61.5033, 55.305801),
#     (61.2, 52.71),
#     (61.616667, 54.083333),
#     (59.083333, 53.35),
#     (54.75, 52.933333),
#     (58.755699, 53.393101),
#     (53.733333, 56.466667),
#     (55.078333, 51.6925),
#     (55.456699, 51.795799)]}},
#  {'id': '5',
#   'kuber_job_id': 'calculate-points-5',
#   'wrf_params': {'MP_PHYSICS': 8,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 11,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '84.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/5',
#   'job_dir_with_results': '/share/calculate_points/results/5',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.0045181633569586,
#    'points_count_by_path': [0, 4, 8],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_1d': {'value': 2.3709016209920706,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_3d': {'value': 2.389831749912793,
#    'points_count_by_path': [0, 25, 29],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_7d': {'value': 2.5160983653445745,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]}},
#  {'id': '6',
#   'kuber_job_id': 'calculate-points-6',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 10,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 10,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '65.00',
#    'LON': '31.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/6',
#   'job_dir_with_results': '/share/calculate_points/results/6',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.5895629995062226,
#    'points_count_by_path': [0, 20, 40],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(29.2225, 65.995556),
#     (29.151667, 66.166111),
#     (28.183333, 67.283333),
#     (32.884722, 66.687222),
#     (34.916667, 64.566667),
#     (33.416667, 63.266667),
#     (28.661667, 63.378056),
#     (27.9, 62.8),
#     (37.050833, 67.350556),
#     (35.883333, 64.233333),
#     (29.668611, 62.546111),
#     (29.316667, 66.366667),
#     (34.283333, 63.766667),
#     (29.177778, 67.162222),
#     (32.354167, 67.169167),
#     (30.816667, 63.833333),
#     (34.8, 64.983333),
#     (28.833333, 63.666667),
#     (33.362222, 67.550833),
#     (36.816667, 65.2),
#     (28.674167, 66.834167),
#     (28.336389, 64.111944),
#     (29.611389, 62.66),
#     (30.05, 63.316667),
#     (28.746667, 64.931389),
#     (30.975278, 62.769722),
#     (34.349722, 66.680556),
#     (35.695833, 65.031389),
#     (29.233333, 63.233333),
#     (33.933333, 65.783333),
#     (27.799444, 63.008333),
#     (34.433333, 62.916667),
#     (28.25, 65.566667),
#     (30.166389, 64.297778),
#     (31.05, 63.15),
#     (36.016944, 66.336944),
#     (31.15, 65.216667)]},
#   'score_result_1d': {'value': 2.0639014968526928,
#    'points_count_by_path': [0, 37, 57],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(29.2225, 65.995556),
#     (29.151667, 66.166111),
#     (28.183333, 67.283333),
#     (32.884722, 66.687222),
#     (34.916667, 64.566667),
#     (33.416667, 63.266667),
#     (28.661667, 63.378056),
#     (27.9, 62.8),
#     (37.050833, 67.350556),
#     (35.883333, 64.233333),
#     (29.668611, 62.546111),
#     (29.316667, 66.366667),
#     (34.283333, 63.766667),
#     (29.177778, 67.162222),
#     (32.354167, 67.169167),
#     (30.816667, 63.833333),
#     (34.8, 64.983333),
#     (28.833333, 63.666667),
#     (33.362222, 67.550833),
#     (36.816667, 65.2),
#     (28.674167, 66.834167),
#     (28.336389, 64.111944),
#     (29.611389, 62.66),
#     (30.05, 63.316667),
#     (28.746667, 64.931389),
#     (30.975278, 62.769722),
#     (34.349722, 66.680556),
#     (35.695833, 65.031389),
#     (29.233333, 63.233333),
#     (33.933333, 65.783333),
#     (27.799444, 63.008333),
#     (34.433333, 62.916667),
#     (28.25, 65.566667),
#     (30.166389, 64.297778),
#     (31.05, 63.15),
#     (36.016944, 66.336944),
#     (31.15, 65.216667)]},
#   'score_result_3d': {'value': 2.9149887923038476,
#    'points_count_by_path': [0, 37, 57],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(29.2225, 65.995556),
#     (29.151667, 66.166111),
#     (28.183333, 67.283333),
#     (32.884722, 66.687222),
#     (34.916667, 64.566667),
#     (33.416667, 63.266667),
#     (28.661667, 63.378056),
#     (27.9, 62.8),
#     (37.050833, 67.350556),
#     (35.883333, 64.233333),
#     (29.668611, 62.546111),
#     (29.316667, 66.366667),
#     (34.283333, 63.766667),
#     (29.177778, 67.162222),
#     (32.354167, 67.169167),
#     (30.816667, 63.833333),
#     (34.8, 64.983333),
#     (28.833333, 63.666667),
#     (33.362222, 67.550833),
#     (36.816667, 65.2),
#     (28.674167, 66.834167),
#     (28.336389, 64.111944),
#     (29.611389, 62.66),
#     (30.05, 63.316667),
#     (28.746667, 64.931389),
#     (30.975278, 62.769722),
#     (34.349722, 66.680556),
#     (35.695833, 65.031389),
#     (29.233333, 63.233333),
#     (33.933333, 65.783333),
#     (27.799444, 63.008333),
#     (34.433333, 62.916667),
#     (28.25, 65.566667),
#     (30.166389, 64.297778),
#     (31.05, 63.15),
#     (36.016944, 66.336944),
#     (31.15, 65.216667)]},
#   'score_result_7d': {'value': 1.6207170528159334,
#    'points_count_by_path': [0, 37, 57],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(29.2225, 65.995556),
#     (29.151667, 66.166111),
#     (28.183333, 67.283333),
#     (32.884722, 66.687222),
#     (34.916667, 64.566667),
#     (33.416667, 63.266667),
#     (28.661667, 63.378056),
#     (27.9, 62.8),
#     (37.050833, 67.350556),
#     (35.883333, 64.233333),
#     (29.668611, 62.546111),
#     (29.316667, 66.366667),
#     (34.283333, 63.766667),
#     (29.177778, 67.162222),
#     (32.354167, 67.169167),
#     (30.816667, 63.833333),
#     (34.8, 64.983333),
#     (28.833333, 63.666667),
#     (33.362222, 67.550833),
#     (36.816667, 65.2),
#     (28.674167, 66.834167),
#     (28.336389, 64.111944),
#     (29.611389, 62.66),
#     (30.05, 63.316667),
#     (28.746667, 64.931389),
#     (30.975278, 62.769722),
#     (34.349722, 66.680556),
#     (35.695833, 65.031389),
#     (29.233333, 63.233333),
#     (33.933333, 65.783333),
#     (27.799444, 63.008333),
#     (34.433333, 62.916667),
#     (28.25, 65.566667),
#     (30.166389, 64.297778),
#     (31.05, 63.15),
#     (36.016944, 66.336944),
#     (31.15, 65.216667)]}},
#  {'id': '7',
#   'kuber_job_id': 'calculate-points-7',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 7,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '62.00',
#    'LON': '153.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/7',
#   'job_dir_with_results': '/share/calculate_points/results/7',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.2311945796188244,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(147.666667, 61.85),
#     (149.633333, 61.116667),
#     (152.416667, 62.916667),
#     (150.7, 60.6),
#     (148.166667, 62.783333),
#     (155.8, 62.516667),
#     (150.666667, 62.8),
#     (150.783333, 59.55),
#     (150.720001, 59.910999),
#     (152.316667, 62.45),
#     (155.883333, 60.716667),
#     (152.383333, 61.133333),
#     (154.266667, 59.65),
#     (158.5, 63.3),
#     (150.675278, 62.096944)]},
#   'score_result_1d': {'value': 1.7686353847572247,
#    'points_count_by_path': [0, 15, 16],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(147.666667, 61.85),
#     (149.633333, 61.116667),
#     (152.416667, 62.916667),
#     (150.7, 60.6),
#     (148.166667, 62.783333),
#     (155.8, 62.516667),
#     (150.666667, 62.8),
#     (150.783333, 59.55),
#     (150.720001, 59.910999),
#     (152.316667, 62.45),
#     (155.883333, 60.716667),
#     (152.383333, 61.133333),
#     (154.266667, 59.65),
#     (158.5, 63.3),
#     (150.675278, 62.096944)]},
#   'score_result_3d': {'value': 1.6994466730061915,
#    'points_count_by_path': [0, 14, 15],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(149.633333, 61.116667),
#     (152.416667, 62.916667),
#     (150.7, 60.6),
#     (148.166667, 62.783333),
#     (155.8, 62.516667),
#     (150.666667, 62.8),
#     (150.783333, 59.55),
#     (150.720001, 59.910999),
#     (152.316667, 62.45),
#     (155.883333, 60.716667),
#     (152.383333, 61.133333),
#     (154.266667, 59.65),
#     (158.5, 63.3),
#     (150.675278, 62.096944)]},
#   'score_result_7d': {'value': 3.4052262044746406,
#    'points_count_by_path': [0, 14, 15],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(149.633333, 61.116667),
#     (152.416667, 62.916667),
#     (150.7, 60.6),
#     (148.166667, 62.783333),
#     (155.8, 62.516667),
#     (150.666667, 62.8),
#     (150.783333, 59.55),
#     (150.720001, 59.910999),
#     (152.316667, 62.45),
#     (155.883333, 60.716667),
#     (152.383333, 61.133333),
#     (154.266667, 59.65),
#     (158.5, 63.3),
#     (150.675278, 62.096944)]}},
#  {'id': '8',
#   'kuber_job_id': 'calculate-points-8',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 1,
#    'KM_OPT': 4,
#    'LAT': '68.00',
#    'LON': '74.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/8',
#   'job_dir_with_results': '/share/calculate_points/results/8',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.6211457431903482,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(72.933333, 66.633333),
#     (72.513611, 70.169722),
#     (68.683333, 66.033333),
#     (72.666667, 65.466667),
#     (78.733333, 67.466667),
#     (66.814444, 69.714167),
#     (76.783333, 66.1),
#     (74.5, 65.833333),
#     (72.884167, 67.687778),
#     (78.4, 65.95),
#     (76.858056, 69.103889)]},
#   'score_result_1d': {'value': 2.049039858285979,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(72.933333, 66.633333),
#     (72.513611, 70.169722),
#     (68.683333, 66.033333),
#     (72.666667, 65.466667),
#     (78.733333, 67.466667),
#     (66.814444, 69.714167),
#     (76.783333, 66.1),
#     (74.5, 65.833333),
#     (78.4, 65.95),
#     (76.858056, 69.103889)]},
#   'score_result_3d': {'value': 2.0189041409755797,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(72.933333, 66.633333),
#     (72.513611, 70.169722),
#     (68.683333, 66.033333),
#     (72.666667, 65.466667),
#     (78.733333, 67.466667),
#     (66.814444, 69.714167),
#     (76.783333, 66.1),
#     (74.5, 65.833333),
#     (78.4, 65.95),
#     (76.858056, 69.103889)]},
#   'score_result_7d': {'value': 2.022685224754387,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(72.933333, 66.633333),
#     (72.513611, 70.169722),
#     (68.683333, 66.033333),
#     (72.666667, 65.466667),
#     (78.733333, 67.466667),
#     (66.814444, 69.714167),
#     (76.783333, 66.1),
#     (74.5, 65.833333),
#     (78.4, 65.95),
#     (76.858056, 69.103889)]}},
#  {'id': '9',
#   'kuber_job_id': 'calculate-points-9',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 10,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 10,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '95.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/9',
#   'job_dir_with_results': '/share/calculate_points/results/9',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.570044907175195,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [0, 0, 3],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_1d': {'value': 3.5092531667647666,
#    'points_count_by_path': [0, 22, 23],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_3d': {'value': 2.8352729627896482,
#    'points_count_by_path': [0, 22, 23],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_7d': {'value': 3.0644512793194973,
#    'points_count_by_path': [0, 21, 22],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (96.119722, 52.470278)]}},
#  {'id': '10',
#   'kuber_job_id': 'calculate-points-10',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 10,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 10,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 1,
#    'KM_OPT': 4,
#    'LAT': '58.00',
#    'LON': '134.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/10',
#   'job_dir_with_results': '/share/calculate_points/results/10',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.9180257989645018,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(138.15, 56.45),
#     (136.15, 57.65),
#     (130.0, 60.466667),
#     (134.45, 60.383333),
#     (130.616667, 58.733333),
#     (133.033333, 59.633333),
#     (137.666667, 59.766667),
#     (131.133333, 56.283333),
#     (135.15, 59.183333)]},
#   'score_result_1d': {'value': 3.123451756221882,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(138.15, 56.45),
#     (136.15, 57.65),
#     (130.0, 60.466667),
#     (134.45, 60.383333),
#     (130.616667, 58.733333),
#     (133.033333, 59.633333),
#     (137.666667, 59.766667),
#     (131.133333, 56.283333),
#     (135.15, 59.183333)]},
#   'score_result_3d': {'value': 1.9080357748359216,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(138.15, 56.45),
#     (136.15, 57.65),
#     (130.0, 60.466667),
#     (134.45, 60.383333),
#     (133.033333, 59.633333),
#     (137.666667, 59.766667),
#     (131.133333, 56.283333),
#     (135.15, 59.183333)]},
#   'score_result_7d': {'value': 6.290542359201354,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(138.15, 56.45),
#     (136.15, 57.65),
#     (130.0, 60.466667),
#     (134.45, 60.383333),
#     (130.616667, 58.733333),
#     (133.033333, 59.633333),
#     (137.666667, 59.766667),
#     (131.133333, 56.283333),
#     (135.15, 59.183333)]}},
#  {'id': '11',
#   'kuber_job_id': 'calculate-points-11',
#   'wrf_params': {'MP_PHYSICS': 8,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 5,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '84.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/11',
#   'job_dir_with_results': '/share/calculate_points/results/11',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.5363228079461648,
#    'points_count_by_path': [0, 4, 8],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_1d': {'value': 3.3733292333178357,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_3d': {'value': 2.635815679993434,
#    'points_count_by_path': [0, 25, 29],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]},
#   'score_result_7d': {'value': 4.25895934152948,
#    'points_count_by_path': [0, 25, 28],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(82.650703, 55.0126),
#     (87.641667, 55.206111),
#     (87.605278, 51.770833),
#     (81.91, 50.63),
#     (82.766667, 52.516667),
#     (80.778333, 53.277222),
#     (87.126944, 52.25),
#     (86.216667, 55.25),
#     (81.891667, 54.367778),
#     (84.208333, 54.335556),
#     (80.340278, 52.021667),
#     (82.170278, 51.155),
#     (81.199444, 51.575556),
#     (83.55, 50.333333),
#     (86.107201, 55.2701),
#     (84.925556, 52.675),
#     (84.385, 55.224722),
#     (82.956944, 54.905556),
#     (80.234398, 50.351299),
#     (86.021389, 51.3875),
#     (82.738889, 55.322222),
#     (80.3, 50.416667),
#     (80.83, 50.76),
#     (80.472222, 54.336111),
#     (83.516667, 53.433333),
#     (83.538498, 53.3638)]}},
#  {'id': '12',
#   'kuber_job_id': 'calculate-points-12',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 5,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 1,
#    'KM_OPT': 4,
#    'LAT': '56.00',
#    'LON': '159.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/12',
#   'job_dir_with_results': '/share/calculate_points/results/12',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.4955870578745554,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(155.583333, 55.583333),
#     (160.833333, 56.316667),
#     (156.737778, 57.095278),
#     (162.691944, 56.236944),
#     (163.233333, 57.65),
#     (155.916667, 54.3)]},
#   'score_result_1d': {'value': 1.51235054247488,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(155.583333, 55.583333),
#     (160.833333, 56.316667),
#     (156.737778, 57.095278),
#     (162.691944, 56.236944),
#     (163.233333, 57.65),
#     (159.983333, 54.116667),
#     (155.916667, 54.3)]},
#   'score_result_3d': {'value': 1.367720300062989,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(155.583333, 55.583333),
#     (160.833333, 56.316667),
#     (156.737778, 57.095278),
#     (162.691944, 56.236944),
#     (163.233333, 57.65),
#     (159.983333, 54.116667),
#     (155.916667, 54.3)]},
#   'score_result_7d': {'value': 4.3764528554989415,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 0],
#    'total_used_meteostations': [(155.583333, 55.583333),
#     (160.833333, 56.316667),
#     (156.737778, 57.095278),
#     (162.691944, 56.236944),
#     (163.233333, 57.65),
#     (159.983333, 54.116667),
#     (155.916667, 54.3)]}},
#  {'id': '13',
#   'kuber_job_id': 'calculate-points-13',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '55.00',
#    'LON': '50.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/13',
#   'job_dir_with_results': '/share/calculate_points/results/13',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.9071074190770618,
#    'points_count_by_path': [0, 5, 10],
#    'dropped_points_count_by_path': [0, 0, 2],
#    'total_used_meteostations': [(46.333333, 55.183333),
#     (52.800833, 54.631944),
#     (48.733333, 57.0),
#     (53.184444, 55.309444),
#     (48.083333, 52.5),
#     (53.133333, 52.433333),
#     (45.166667, 57.133333),
#     (49.278702, 55.606201),
#     (50.216667, 53.25),
#     (48.8027, 54.401001),
#     (47.347301, 56.090302),
#     (52.45, 53.616667),
#     (51.283333, 52.616667),
#     (50.412778, 54.4925),
#     (51.033333, 56.233333),
#     (48.333333, 54.316667),
#     (49.6, 54.233333),
#     (54.147222, 54.024722),
#     (48.4, 53.183333),
#     (50.466667, 52.383333),
#     (50.164299, 53.504902),
#     (45.5, 55.533333),
#     (53.45, 56.833333),
#     (49.204444, 55.74),
#     (46.583333, 54.816667),
#     (48.791111, 54.948056),
#     (49.95, 57.55),
#     (52.044167, 55.758889),
#     (46.433333, 53.05),
#     (48.833333, 53.6),
#     (49.864167, 56.091389),
#     (46.416667, 53.85),
#     (49.433333, 52.983333),
#     (46.366667, 52.333333),
#     (46.583333, 56.333333),
#     (47.779167, 56.64),
#     (53.069444, 55.718611),
#     (54.75, 57.083333),
#     (53.733333, 56.466667),
#     (52.092499, 55.564701),
#     (46.7, 54.483333),
#     (51.1, 54.416667),
#     (47.516667, 53.15)]},
#   'score_result_1d': {'value': 2.760709038585712,
#    'points_count_by_path': [0, 43, 48],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(46.333333, 55.183333),
#     (52.800833, 54.631944),
#     (48.733333, 57.0),
#     (53.184444, 55.309444),
#     (48.083333, 52.5),
#     (53.133333, 52.433333),
#     (45.166667, 57.133333),
#     (49.278702, 55.606201),
#     (50.216667, 53.25),
#     (48.8027, 54.401001),
#     (47.347301, 56.090302),
#     (52.45, 53.616667),
#     (51.283333, 52.616667),
#     (50.412778, 54.4925),
#     (51.033333, 56.233333),
#     (48.333333, 54.316667),
#     (49.6, 54.233333),
#     (54.147222, 54.024722),
#     (48.4, 53.183333),
#     (50.466667, 52.383333),
#     (50.164299, 53.504902),
#     (45.5, 55.533333),
#     (53.45, 56.833333),
#     (49.204444, 55.74),
#     (46.583333, 54.816667),
#     (48.791111, 54.948056),
#     (49.95, 57.55),
#     (52.044167, 55.758889),
#     (46.433333, 53.05),
#     (48.833333, 53.6),
#     (49.864167, 56.091389),
#     (46.416667, 53.85),
#     (49.433333, 52.983333),
#     (46.366667, 52.333333),
#     (46.583333, 56.333333),
#     (47.779167, 56.64),
#     (53.069444, 55.718611),
#     (54.75, 57.083333),
#     (53.733333, 56.466667),
#     (52.092499, 55.564701),
#     (46.7, 54.483333),
#     (51.1, 54.416667),
#     (47.516667, 53.15)]},
#   'score_result_3d': {'value': 1.9489709271598363,
#    'points_count_by_path': [0, 43, 48],
#    'dropped_points_count_by_path': [2, 0, 0],
#    'total_used_meteostations': [(46.333333, 55.183333),
#     (52.800833, 54.631944),
#     (48.733333, 57.0),
#     (53.184444, 55.309444),
#     (48.083333, 52.5),
#     (53.133333, 52.433333),
#     (45.166667, 57.133333),
#     (49.278702, 55.606201),
#     (50.216667, 53.25),
#     (48.8027, 54.401001),
#     (47.347301, 56.090302),
#     (52.45, 53.616667),
# ...
#     (40.35, 56.116667),
#     (34.55, 57.533333),
#     (36.7, 55.383333),
#     (39.25, 53.783333),
#     (38.116667, 53.15),
#     (37.6, 52.433333),
#     (39.516667, 52.7),
#     (38.683333, 55.766667),
#     (37.4146, 55.972599),
#     (37.616667, 54.233333),
#     (40.483333, 52.883333),
#     (38.516667, 52.633333),
#     (39.416667, 57.2),
#     (36.483333, 55.016667),
#     (37.261501, 55.591499),
#     (35.35, 54.1),
#     (37.507198, 55.5117),
#     (41.933333, 54.366667),
#     (38.133333, 54.0),
#     (40.966667, 56.95),
#     (34.316667, 53.25),
#     (38.150002, 55.553299),
#     (33.75, 53.533333),
#     (36.533333, 53.383333),
#     (36.0, 52.933333),
#     (38.3, 57.5),
#     (41.333333, 52.8),
#     (36.75, 56.35),
#     (37.566667, 57.333333),
#     (36.3, 52.316667),
#     (36.816667, 55.9)]},
#   'score_result_3d': {'value': 2.1238269234006877,
#    'points_count_by_path': [0, 49, 57],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(40.157398, 57.560699),
#     (33.766667, 52.583333),
#     (38.15, 54.833333),
#     (40.116667, 53.716667),
#     (37.9063, 55.408798),
#     (39.7, 54.633333),
#     (35.033333, 55.516667),
#     (37.616667, 55.833333),
#     (42.116667, 55.333333),
#     (36.366669, 54.549999),
#     (39.5378, 52.702801),
#     (40.65, 55.6),
#     (41.766667, 54.95),
#     (41.8, 53.45),
#     (34.4, 55.166667),
#     (34.016667, 54.416667),
#     (35.866667, 56.883333),
#     (34.916667, 56.483333),
#     (40.35, 56.116667),
#     (34.55, 57.533333),
#     (36.7, 55.383333),
#     (39.25, 53.783333),
#     (38.116667, 53.15),
#     (37.6, 52.433333),
#     (39.516667, 52.7),
#     (38.683333, 55.766667),
#     (37.4146, 55.972599),
#     (37.616667, 54.233333),
#     (40.483333, 52.883333),
#     (38.516667, 52.633333),
#     (39.416667, 57.2),
#     (36.483333, 55.016667),
#     (37.261501, 55.591499),
#     (35.35, 54.1),
#     (37.507198, 55.5117),
#     (41.933333, 54.366667),
#     (38.133333, 54.0),
#     (40.966667, 56.95),
#     (34.316667, 53.25),
#     (38.150002, 55.553299),
#     (33.75, 53.533333),
#     (36.533333, 53.383333),
#     (36.0, 52.933333),
#     (38.3, 57.5),
#     (41.333333, 52.8),
#     (36.75, 56.35),
#     (37.566667, 57.333333),
#     (36.3, 52.316667),
#     (36.816667, 55.9)]},
#   'score_result_7d': {'value': 1.7279550600657279,
#    'points_count_by_path': [0, 49, 57],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(40.157398, 57.560699),
#     (33.766667, 52.583333),
#     (38.15, 54.833333),
#     (40.116667, 53.716667),
#     (37.9063, 55.408798),
#     (39.7, 54.633333),
#     (35.033333, 55.516667),
#     (37.616667, 55.833333),
#     (42.116667, 55.333333),
#     (36.366669, 54.549999),
#     (39.5378, 52.702801),
#     (40.65, 55.6),
#     (41.766667, 54.95),
#     (41.8, 53.45),
#     (34.4, 55.166667),
#     (34.016667, 54.416667),
#     (35.866667, 56.883333),
#     (34.916667, 56.483333),
#     (40.35, 56.116667),
#     (34.55, 57.533333),
#     (36.7, 55.383333),
#     (39.25, 53.783333),
#     (38.116667, 53.15),
#     (37.6, 52.433333),
#     (39.516667, 52.7),
#     (38.683333, 55.766667),
#     (37.4146, 55.972599),
#     (37.616667, 54.233333),
#     (40.483333, 52.883333),
#     (38.516667, 52.633333),
#     (39.416667, 57.2),
#     (36.483333, 55.016667),
#     (37.261501, 55.591499),
#     (35.35, 54.1),
#     (37.507198, 55.5117),
#     (41.933333, 54.366667),
#     (38.133333, 54.0),
#     (40.966667, 56.95),
#     (34.316667, 53.25),
#     (38.150002, 55.553299),
#     (33.75, 53.533333),
#     (36.533333, 53.383333),
#     (36.0, 52.933333),
#     (38.3, 57.5),
#     (41.333333, 52.8),
#     (36.75, 56.35),
#     (37.566667, 57.333333),
#     (36.3, 52.316667),
#     (36.816667, 55.9)]}},
#  {'id': '1026',
#   'kuber_job_id': 'calculate-points-1026',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 3,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 1,
#    'KM_OPT': 4,
#    'LAT': '68.00',
#    'LON': '56.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/1026',
#   'job_dir_with_results': '/share/calculate_points/results/1026',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.2318880066552933,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(52.5625, 66.258333),
#     (61.657778, 69.783333),
#     (56.905833, 65.984167),
#     (59.091111, 70.446667),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (57.985556, 68.803889),
#     (49.301111, 68.780278),
#     (55.496667, 68.540556),
#     (52.266667, 65.433333)]},
#   'score_result_1d': {'value': 1.4279091942313644,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(61.657778, 69.783333),
#     (56.905833, 65.984167),
#     (59.091111, 70.446667),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (57.985556, 68.803889),
#     (49.301111, 68.780278),
#     (55.496667, 68.540556),
#     (52.266667, 65.433333)]},
#   'score_result_3d': {'value': 1.8858500794643507,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(61.657778, 69.783333),
#     (56.905833, 65.984167),
#     (59.091111, 70.446667),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (57.985556, 68.803889),
#     (49.301111, 68.780278),
#     (55.496667, 68.540556),
#     (52.266667, 65.433333)]},
#   'score_result_7d': {'value': 5.075909187933971,
#    'points_count_by_path': [0, 0, 0],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(61.657778, 69.783333),
#     (56.905833, 65.984167),
#     (59.091111, 70.446667),
#     (60.754444, 66.471111),
#     (53.0175, 67.625),
#     (57.985556, 68.803889),
#     (49.301111, 68.780278),
#     (55.496667, 68.540556),
#     (52.266667, 65.433333)]}},
#  {'id': '1027',
#   'kuber_job_id': 'calculate-points-1027',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 5,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 5,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 0,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '53.00',
#    'LON': '95.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/1027',
#   'job_dir_with_results': '/share/calculate_points/results/1027',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.0174497063303005,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [0, 0, 3],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_1d': {'value': 2.3350765997942267,
#    'points_count_by_path': [0, 22, 23],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_3d': {'value': 2.3269202564669587,
#    'points_count_by_path': [0, 22, 23],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (96.119722, 52.470278),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (94.2, 53.686111)]},
#   'score_result_7d': {'value': 2.2935022165925067,
#    'points_count_by_path': [0, 21, 22],
#    'dropped_points_count_by_path': [3, 0, 0],
#    'total_used_meteostations': [(93.685, 51.128333),
#     (92.403333, 53.27),
#     (93.915833, 52.144722),
#     (94.9, 55.27),
#     (90.848333, 55.088333),
#     (99.033333, 54.883333),
#     (91.583333, 54.191667),
#     (94.491667, 51.710278),
#     (93.240278, 52.804167),
#     (91.385002, 53.740002),
#     (92.883333, 53.59),
#     (92.088889, 55.355556),
#     (93.434722, 54.361111),
#     (91.625, 55.385),
#     (95.577778, 51.478889),
#     (93.013333, 52.256667),
#     (96.966667, 54.216667),
#     (92.15, 54.365),
#     (93.383889, 55.121944),
#     (91.7, 53.716667),
#     (96.119722, 52.470278)]}},
#  {'id': '1028',
#   'kuber_job_id': 'calculate-points-1028',
#   'wrf_params': {'MP_PHYSICS': 17,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 4,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 10,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 10,
#    'CU_PHYSICS': 3,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '60.00',
#    'LON': '59.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/1028',
#   'job_dir_with_results': '/share/calculate_points/results/1028',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 2.190091100765564,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_1d': {'value': 3.287622501221952,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_3d': {'value': 3.9069375934558668,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_7d': {'value': 4.5883492489351365,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]}},
#  {'id': '976',
#   'kuber_job_id': 'calculate-points-976',
#   'wrf_params': {'MP_PHYSICS': 18,
#    'RA_LW_PHYSICS': 4,
#    'RA_SW_PHYSICS': 5,
#    'RADT': 6,
#    'SF_SFCLAY_PHYSICS': 1,
#    'SF_SURFACE_PHYSICS': 2,
#    'SF_URBAN_PHYSICS': 1,
#    'BL_PBL_PHYSICS': 7,
#    'CU_PHYSICS': 16,
#    'DIFF_6TH_OPT': 2,
#    'DIFF_OPT': 2,
#    'KM_OPT': 4,
#    'LAT': '60.00',
#    'LON': '59.00',
#    'E_WE': 100,
#    'E_SN': 100,
#    'DX': 6000,
#    'TIME_STEP': 30,
#    'START_DATE': '2020-07-15_00:00:00',
#    'END_DATE': '2020-07-22_00:00:00',
#    'INTERVAL_SECONDS': '10800'},
#   'local_dir_with_results': '/home/jovyan/work/ship/calculate_points/results/976',
#   'job_dir_with_results': '/share/calculate_points/results/976',
#   'score': None,
#   'error_msg': None,
#   'score_result_3h': {'value': 1.965970686574275,
#    'points_count_by_path': [0, 1, 2],
#    'dropped_points_count_by_path': [0, 0, 1],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_1d': {'value': 2.413282752744803,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_3d': {'value': 2.9877218469825277,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]},
#   'score_result_7d': {'value': 3.1723281012694473,
#    'points_count_by_path': [0, 17, 18],
#    'dropped_points_count_by_path': [1, 0, 0],
#    'total_used_meteostations': [(56.866667, 61.833333),
#     (55.383333, 57.716667),
#     (53.683333, 61.683333),
#     (56.516667, 60.4),
#     (56.666667, 58.0),
#     (60.783333, 58.866667),
#     (60.45, 60.683333),
#     (58.85, 58.516667),
#     (64.216667, 60.316667),
#     (60.866667, 62.433333),
#     (62.333333, 59.433333),
#     (58.216667, 57.35),
#     (60.533333, 59.6),
#     (54.35, 60.283333),
#     (56.021198, 57.914501),
#     (54.65, 59.016667),
#     (60.066667, 57.883333)]}},
#  ...]

# %%
with open(os.path.join("/home/jovyan/work/ship/calculate_points", "jobs_state_new.json")) as f:
    state = json.load(f)
    completed_jobs = state["completed_jobs"]

# %%
used_meteostations_coords = set()

job = completed_jobs[1702]

def process_coords(field_name):
    for meteo_coords in job[field_name]['total_used_meteostations']:
        used_meteostations_coords.add((meteo_coords[0], meteo_coords[1]))

process_coords('score_result_3h')

process_coords('score_result_1d')

process_coords('score_result_3d')

process_coords('score_result_7d')

# %%
sorted(used_meteostations_coords) # long, lat
# Out:
# [(33.75, 53.533333),
#  (33.766667, 52.583333),
#  (34.016667, 54.416667),
#  (34.176399, 53.214199),
#  (34.316667, 53.25),
#  (34.4, 55.166667),
#  (34.55, 57.533333),
#  (34.916667, 56.483333),
#  (35.033333, 55.516667),
#  (35.35, 54.1),
#  (35.866667, 56.883333),
#  (36.0, 52.933333),
#  (36.3, 52.316667),
#  (36.366669, 54.549999),
#  (36.483333, 55.016667),
#  (36.533333, 53.383333),
#  (36.7, 55.383333),
#  (36.75, 56.35),
#  (36.816667, 55.9),
#  (37.261501, 55.591499),
#  (37.4146, 55.972599),
#  (37.507198, 55.5117),
#  (37.566667, 57.333333),
#  (37.6, 52.433333),
#  (37.616667, 54.233333),
#  (37.616667, 55.833333),
#  (37.9063, 55.408798),
#  (38.116667, 53.15),
#  (38.133333, 54.0),
#  (38.15, 54.833333),
#  (38.150002, 55.553299),
#  (38.3, 57.5),
#  (38.516667, 52.633333),
#  (38.683333, 55.766667),
#  (39.25, 53.783333),
#  (39.416667, 57.2),
#  (39.516667, 52.7),
#  (39.5378, 52.702801),
#  (39.7, 54.633333),
#  (40.116667, 53.716667),
#  (40.157398, 57.560699),
#  (40.35, 56.116667),
#  (40.483333, 52.883333),
#  (40.65, 55.6),
#  (40.966667, 56.95),
#  (41.333333, 52.8),
#  (41.766667, 54.95),
#  (41.8, 53.45),
#  (41.933333, 54.366667),
#  (42.116667, 55.333333)]

# %%
dd = pandas.read_csv("/home/jovyan/work/ship/calculate_points/last_prepared_noaa_data_morozyto.csv")

# %%
def g(coords):
    filtered_dd = dd[(dd["longitude"] == coords[0]) & (dd["latitude"] == coords[1])]
    station_ids = filtered_dd["station_id"].unique()
    assert(len(station_ids) == 1)
    return station_ids[0]

station_ids = [g(coords) for coords in used_meteostations_coords]

# %%
print(station_ids)
# Out:
# [34189, 34192, 49432, 49501, 49527, 34191, 49513, 49484, 49498, 49486, 49502, 34182, 34204, 49489, 49503, 49528, 49422, 49427, 49471, 49419, 49488, 49415, 49526, 49534, 49549, 49536, 49487, 34193, 49511, 49537, 49535, 49463, 49496, 34214, 49510, 34198, 49515, 49525, 49466, 49430, 34190, 49429, 49524, 49533, 49462, 49539, 49473, 49461, 49547, 49497]
